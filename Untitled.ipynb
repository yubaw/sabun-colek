# %%
import docx

# %%
doc = docx.Document(r'C:\Users\lenovo\Documents\soal bpk\FIKIH (WAJIB).docx')
allText = []
for docpara in doc.paragraphs:
    allText.append(docpara.text)

# %%
allText
# Out:
# ['KEMENTRIAN AGAMA REPUBLIK INDONESIA',
#  'MADRASAH ALIYAH NEGERI 1 KOTA BANDUNG',
#  'UJIAN MADRASAH TAHUN PELAJARAN 2020 / 2021',
#  '',
#  'Pilihlah salah sati jawaban yang paling benar A, B, C, D, atau D',
#  'Ruang lingkup pembahasn ilmu Fikh pada garis besarnya meliputi dua bidang pokok, yaitu bidang ibadah dan bidang hukum muamalah. Peranyataan berikut ini yang merupakan bidang  ibadah adalah....',
#  'Jual beli, syirkah, dan haji\t\t\t',
#  'Salam’ sewa menyewa, dan puasa\t\t',
#  'Perkawinan, warisan dan zakat',
#  'Jual beli, salam dan perkawina, ',
#  'Haji dan umroh',
#  '',
#  'Orang-orang berikut ini adalah beberapa anggota keluarga yang ditinggalkan oleh Pak Robet yang beragama Islam pada saat beliau meninggal dunia dalam sebuah kecelakaan lalu lintas: ',
#  'Paman',
#  '2 orang anak laki-laki',
#  '1 orang anak laki-laki ( beragama Nasrani )',
#  'Istri',
#  'Kakak laki-laki (beragama Nasrani)',
#  '1 orang anak perempuan',
# ...

# %%
from pdf2image import convert_from_path
from tkinter import *
from tkinter import messagebox
 
 
def pdf2img():
    try:
        images = convert_from_path(str(e1.get()))
        for img in images:
            img.save('new_folder\output.jpg', 'JPEG')
 
    except  :
        Result = "NO pdf found"
        messagebox.showinfo("Result", Result)
 
    else:
        Result = "success"
        messagebox.showinfo("Result", Result)
 
 
 
master = Tk()
Label(master, text="File Location").grid(row=0, sticky=W) 
 
e1 = Entry(master)
e1.grid(row=0, column=1)
 
b = Button(master, text="Convert", command=pdf2img)
b.grid(row=0, column=2,columnspan=2, rowspan=2,padx=5, pady=5)
  
mainloop()

# %%
# !pip install python-poppler
# Out:
# ...
#   Running setup.py clean for python-poppler
# Failed to build python-poppler
# ...
#     Running setup.py install for python-poppler: started
#     Running setup.py install for python-poppler: finished with status 'error'
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\lenovo\anaconda3\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\lenovo\\AppData\\Local\\Temp\\pip-install-9wfyq9gd\\python-poppler\\setup.py'"'"'; __file__='"'"'C:\\Users\\lenovo\\AppData\\Local\\Temp\\pip-install-9wfyq9gd\\python-poppler\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\lenovo\AppData\Local\Temp\pip-wheel-svqa9yvl'
#        cwd: C:\Users\lenovo\AppData\Local\Temp\pip-install-9wfyq9gd\python-poppler\
#   Complete output (71 lines):
#   running bdist_wheel
#   running build
#   running build_py
# ...
